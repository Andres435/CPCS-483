# %% [markdown]
# # Convolutional Neural Network

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
#Changing the directory
os.chdir('/content/drive/My Drive/CPCS 483/HW12')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.14.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset - preprocessing

# %%
train_datagen = ImageDataGenerator (rescale = 1./255,shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/train', target_size = (64, 64), batch_size = 32, class_mode = 'binary')
# Out:
# Found 557 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test', target_size = (64, 64), batch_size = 32, class_mode = 'binary')
# Out:
# Found 140 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initializing the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer
# Step 1 - Convolution filters = numbers of feature detectors, kernel = size of feature detector 3 by 3, input shape of
# images RGB, black and white instead of 3 we need to choose 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# Step 2 - Pooling the size of the squre, stride the move or sliding

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding the second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf. keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Flattering

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 18/18 [==============================] - 9s 431ms/step - loss: 0.7232 - accuracy: 0.4883 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 2/25
# 18/18 [==============================] - 9s 526ms/step - loss: 0.6912 - accuracy: 0.5045 - val_loss: 0.6910 - val_accuracy: 0.5000
# Epoch 3/25
# 18/18 [==============================] - 9s 505ms/step - loss: 0.6871 - accuracy: 0.5386 - val_loss: 0.6842 - val_accuracy: 0.5429
# Epoch 4/25
# 18/18 [==============================] - 8s 405ms/step - loss: 0.6684 - accuracy: 0.5655 - val_loss: 0.6774 - val_accuracy: 0.6000
# Epoch 5/25
# 18/18 [==============================] - 10s 547ms/step - loss: 0.6419 - accuracy: 0.6373 - val_loss: 0.6635 - val_accuracy: 0.6071
# Epoch 6/25
# 18/18 [==============================] - 8s 420ms/step - loss: 0.6118 - accuracy: 0.6625 - val_loss: 0.6890 - val_accuracy: 0.5714
# Epoch 7/25
# ...

# %% [markdown]
# ## Part 4 - Making the predictions and evaluating the model

# %% [markdown]
# loading the image using load img function, same size of image has to be as same as the training, img to array that predict method accept, add the extra dimension of the batch, where we wanna add the batch dimession which is the first dimenssion. O is for the batch and 0 first element in that batch

# %%
import numpy as np
from keras.preprocessing import image

# %%
test_image = image.load_img('dataset/single_prediction/dog_or_cat.tiff', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims (test_image, axis = 0)
result = cnn.predict (test_image)
training_set.class_indices
if result [0] [0] == 1:
  prediction = 'Is a dog'
else:
  prediction = 'Is a cat'
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
print(prediction)
# Out:
# Is a dog
